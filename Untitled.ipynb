# %%
import nbformat

# Reading the notebooks

n1 = nbformat.read('01.file.ipynb', 4)
n2 = nbformat.read('02.file.ipynb', 4)
n3 = nbformat.read('03.file.ipynb', 4)
n4 = nbformat.read('04.file.ipynb', 4)

# Creating a new notebook
final_notebook = nbformat.v4.new_notebook(metadata=n1.metadata)

# Concatenating the notebooks
final_notebook.cells = n1.cells + n2.cells +n3.cells + n4.cells 

# Saving the new notebook 
nbformat.write(final_notebook, 'Proje=1_1234.ipynb')

# %%
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt
import seaborn as sb
import seaborn as sns

# %%
        #Bismillahirrahmanirrahim. Haydi Hayırlısı bakalım

# %%
#Şimdi ne yapıyoruz yazı yazmaya başlıyoruz
#Henüz ALT-gr tuşununu yerine alışamadım, ama daha iyi olacak diye ümidim var.
#Tüm tuşları ilk 3 sıraya kaydırdığım için artık 1,2,3,4 .. sayılar hariç 
# hepsini klavyeden yazmayı ümit ediyorum. Yani yazarken kopmuyacağım.
# Tabii şimdilik parmaklarım eski alıştığı yerlere gidiyor öncelikle sonra aklıma gelip yerini varmadan değiştiriyorum.
# Alt-gr a basmak gerçekten zor Sağ elim şimdiden 4 satırda  ağrımaya başladı

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def prc(x):return round(x*100,1)  #yüzde (%) göstriminde kolaylık için
def celcius(x): return (x-32)/1.8   # fahrenheit i celcius a çevirmek için

we=pd.read_csv("weather.csv")
we.head()
# Out:
#        STATION        DATE  AWND  TAVG  TMAX  TMIN  WT01  WT02  WT03  WT04  \
# 0  USC00379423  2005-01-01   NaN   NaN  47.0  28.0   NaN   NaN   NaN   NaN
# 1  USC00379423  2005-01-02   NaN   NaN  52.0  24.0   NaN   NaN   NaN   NaN
# 2  USC00379423  2005-01-03   NaN   NaN  48.0  27.0   NaN   NaN   NaN   NaN
# 3  USC00379423  2005-01-04   NaN   NaN  54.0  40.0   NaN   NaN   NaN   NaN
# 4  USC00379423  2005-01-05   NaN   NaN  44.0  31.0   NaN   NaN   NaN   NaN
#
#    ...  WT11  WT13  WT14  WT15  WT16  WT17  WT18  WT19  WT21  WT22
# 0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 26 columns]

# %%
we.shape
# Out:
# (8022, 26)

# %%
we.isnull().sum()
# Out:
# STATION       0
# DATE          0
# AWND       4005
# TAVG       6805
# TMAX         17
# TMIN         26
# WT01       6245
# WT02       7801
# WT03       7795
# WT04       7903
# WT05       7662
# WT06       7997
# WT07       7943
# WT08       7618
# WT09       7953
# WT10       8020
# WT11       8019
# WT13       6847
# WT14       7447
# WT15       8016
# WT16       6696
# WT17       8010
# WT18       7677
# WT19       8018
# WT21       8004
# WT22       7990
# dtype: int64

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
we[["TMIN","TAVG","TMAX"]].plot.box(grid=True)
# Out:
# <AxesSubplot:>

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
we[["TMIN","TAVG","TMAX"]].plot.box(grid=True)
# Out:
# <AxesSubplot:>

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %% [raw]
# round(we[["TMIN","M,"TMAX"]].describe(),1)
#
#
#
#
#
#
#
# import pandas as pd
# ri=pd.read_csv("police.csv")
# ri.head()
#
#
#
#
#
#
#
# round(we[["TMIN","TMAX","TMAX"]].describe(),1)
#
#
#
# round(we[["TMIN","TMAX","TMAX"]].describe(),1)
#
#
#
#
#
#
#
# round(we[["TMIN","TMAX","TMAX"]].describe(),1)

# %%
import pandas as pd
ri=pd.read_csv("police.csv")
ri.head()
# Out:
# C:\Users\C\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# ...

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
round(we[["TMIN","TMAX","TMAX"]].describe(),1)
# Out:
#          TMIN    TMAX    TMAX
# count  7996.0  8005.0  8005.0
# mean     42.1    61.2    61.2
# std      17.4    18.5    18.5
# min     -10.0    13.0    13.0
# 25%      29.0    46.0    46.0
# 50%      42.0    62.0    62.0
# 75%      57.0    77.0    77.0
# max      77.0   102.0   102.0

# %%
ri.dtypes
# Out:
# id                        object
# state                     object
# stop_date                 object
# stop_time                 object
# location_raw              object
# county_name              float64
# county_fips              float64
# fine_grained_location    float64
# police_department         object
# driver_gender             object
# driver_age_raw           float64
# driver_age               float64
# driver_race_raw           object
# driver_race               object
# violation_raw             object
# violation                 object
# search_conducted          object
# search_type_raw           object
# search_type               object
# contraband_found            bool
# stop_outcome              object
# is_arrested               object
# stop_duration             object
# out_of_state              object
# drugs_related_stop          bool
# district                  object
# dtype: object

# %%
ri.isnull().sum()
# Out:
# id                            0
# state                         0
# stop_date                    10
# stop_time                    10
# location_raw                  0
# county_name              509681
# county_fips              509681
# fine_grained_location    509681
# police_department            10
# driver_gender             29097
# driver_age_raw            29049
# driver_age                30695
# driver_race_raw           29073
# driver_race               29073
# violation_raw             29073
# violation                 29073
# search_conducted             10
# search_type_raw          491919
# search_type              491919
# contraband_found              0
# stop_outcome              29073
# is_arrested               29073
# stop_duration             29073
# out_of_state              29881
# drugs_related_stop            0
# district                      0
# dtype: int64

# %%
ri.dtypes
# Out:
# id                        object
# state                     object
# stop_date                 object
# stop_time                 object
# location_raw              object
# county_name              float64
# county_fips              float64
# fine_grained_location    float64
# police_department         object
# driver_gender             object
# driver_age_raw           float64
# driver_age               float64
# driver_race_raw           object
# driver_race               object
# violation_raw             object
# violation                 object
# search_conducted          object
# search_type_raw           object
# search_type               object
# contraband_found            bool
# stop_outcome              object
# is_arrested               object
# stop_duration             object
# out_of_state              object
# drugs_related_stop          bool
# district                  object
# dtype: object

# %%
ri.shapem
# Out:
# (509681, 26)

# %%
ri.drop(["state","county_name","county_fips","fine_grained_location"], axis=1, inplace=True)

# %%
ri.shape
# Out:
# (509681, 22)

# %%
ri.isnull().sum()
# Out:
# id                         0
# stop_date                 10
# stop_time                 10
# location_raw               0
# police_department         10
# driver_gender          29097
# driver_age_raw         29049
# driver_age             30695
# driver_race_raw        29073
# driver_race            29073
# violation_raw          29073
# violation              29073
# search_conducted          10
# search_type_raw       491919
# search_type           491919
# contraband_found           0
# stop_outcome           29073
# is_arrested            29073
# stop_duration          29073
# out_of_state           29881
# drugs_related_stop         0
# district                   0
# dtype: int64

# %%
ri.drop(["search_type_raw","search_type"], axis=1, inplace=True)

# %%
ri.shape
# Out:
# (509681, 20)

# %%
ri.isnull().sum()
# Out:
# id                        0
# stop_date                10
# stop_time                10
# location_raw              0
# police_department        10
# driver_gender         29097
# driver_age_raw        29049
# driver_age            30695
# driver_race_raw       29073
# driver_race           29073
# violation_raw         29073
# violation             29073
# search_conducted         10
# contraband_found          0
# stop_outcome          29073
# is_arrested           29073
# stop_duration         29073
# out_of_state          29881
# drugs_related_stop        0
# district                  0
# dtype: int64

# %%
ri=ri.dropna(subset=["driver_gender"])

# %%
ri.isnull().sum()
# Out:
# id                       0
# stop_date                0
# stop_time                0
# location_raw             0
# police_department        0
# driver_gender            0
# driver_age_raw           1
# driver_age            1638
# driver_race_raw          0
# driver_race              0
# violation_raw            0
# violation                0
# search_conducted         0
# contraband_found         0
# stop_outcome             0
# is_arrested              0
# stop_duration            0
# out_of_state           808
# drugs_related_stop       0
# district                 0
# dtype: int64

# %%
ri=ri.dropna(subset=["driver_age_raw","driver_age","out_of_state"])
ri.isnull().sum()
# Out:
# id                    0
# stop_date             0
# stop_time             0
# location_raw          0
# police_department     0
# driver_gender         0
# driver_age_raw        0
# driver_age            0
# driver_race_raw       0
# driver_race           0
# violation_raw         0
# violation             0
# search_conducted      0
# contraband_found      0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# out_of_state          0
# drugs_related_stop    0
# district              0
# dtype: int64

# %%
ri.dtypes
# Out:
# id                     object
# stop_date              object
# stop_time              object
# location_raw           object
# police_department      object
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race_raw        object
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted       object
# contraband_found         bool
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# out_of_state           object
# drugs_related_stop       bool
# district               object
# dtype: object

# %%
ri.is_arrested=ri.is_arrested.astype("bool")
ri.dtypes
# Out:
# id                     object
# stop_date              object
# stop_time              object
# location_raw           object
# police_department      object
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race_raw        object
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted       object
# contraband_found         bool
# stop_outcome           object
# is_arrested              bool
# stop_duration          object
# out_of_state           object
# drugs_related_stop       bool
# district               object
# dtype: object

# %%
combine=ri.stop_date +" "+ ri.stop_time
ri["stop_datetime"]=combine.astype("datetime64")
ri.head()
# Out:
#               id   stop_date stop_time location_raw police_department  \
# 0  RI-2005-00001  2005-01-02     01:55      Zone K1               600
# 1  RI-2005-00002  2005-01-02     20:30      Zone X4               500
# 3  RI-2005-00004  2005-01-04     12:55      Zone X4               500
# 4  RI-2005-00005  2005-01-06     01:30      Zone X4               500
# 5  RI-2005-00006  2005-01-12     08:05      Zone X1                 0
#
#   driver_gender  driver_age_raw  driver_age driver_race_raw driver_race  ...  \
# 0             M          1985.0        20.0               W       White  ...
# 1             M          1987.0        18.0               W       White  ...
# 3             M          1986.0        19.0               W       White  ...
# 4             M          1978.0        27.0               B       Black  ...
# 5             M          1973.0        32.0               B       Black  ...
#
#    violation search_conducted contraband_found  stop_outcome is_arrested  \
# ...

# %%
ri=ri.set_index("stop_datetime")
ri.head()
# Out:
#                                 id   stop_date stop_time location_raw  \
# stop_datetime
# 2005-01-02 01:55:00  RI-2005-00001  2005-01-02     01:55      Zone K1
# 2005-01-02 20:30:00  RI-2005-00002  2005-01-02     20:30      Zone X4
# 2005-01-04 12:55:00  RI-2005-00004  2005-01-04     12:55      Zone X4
# 2005-01-06 01:30:00  RI-2005-00005  2005-01-06     01:30      Zone X4
# 2005-01-12 08:05:00  RI-2005-00006  2005-01-12     08:05      Zone X1
#
#                     police_department driver_gender  driver_age_raw  \
# stop_datetime
# 2005-01-02 01:55:00               600             M          1985.0
# 2005-01-02 20:30:00               500             M          1987.0
# 2005-01-04 12:55:00               500             M          1986.0
# 2005-01-06 01:30:00               500             M          1978.0
# 2005-01-12 08:05:00                 0             M          1973.0
#
#                      driver_age driver_race_raw driver_race  \
# stop_datetime
# ...

# %%
.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({"name": [np.nan, 'Batman', 'Spiderman'],
                   "toy": [np.nan, 'Batmobile', 'Spiderman toy'],
                   "born": [pd.NaT, pd.Timestamp("1956-06-26"),
                            pd.NaT],
                 "Age": [pd.NaT, pd.NaT,
                            pd.NaT]})

# %%
df
# Out:
#         name            toy       born Age
# 0        NaN            NaN        NaT NaT
# 1     Batman      Batmobile 1956-06-26 NaT
# 2  Spiderman  Spiderman toy        NaT NaT

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [name, toy, born, Age]
# Index: []

# %%
df.dropna(axis="columns")
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
df.dropna(how="all")
# Out:
#         name            toy       born Age
# 1     Batman      Batmobile 1956-06-26 NaT
# 2  Spiderman  Spiderman toy        NaT NaT

# %%
df.dropna(how="all",axis=1)
# Out:
#         name            toy       born
# 0        NaN            NaN        NaT
# 1     Batman      Batmobile 1956-06-26
# 2  Spiderman  Spiderman toy        NaT

# %%
df.dropna(thresh=1)
# Out:
#         name            toy       born Age
# 1     Batman      Batmobile 1956-06-26 NaT
# 2  Spiderman  Spiderman toy        NaT NaT

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(15,6),
columns=list('ABCDEF'))

# %%
df
# Out:
#            A         B         C         D         E         F
# 0   1.576872 -0.224942  0.858896  0.652953  0.267312  0.184589
# 1  -1.619639  0.668527  0.365563  1.038478  0.215447  0.301900
# 2   0.812383  1.049011 -2.496879  0.037445 -1.471315  0.410242
# 3   0.449761 -0.161947 -2.504827 -0.675809  0.367491 -0.219055
# 4  -0.020511  0.490512 -2.327432 -0.481929 -0.732653  2.122390
# 5  -0.066968  0.393548  0.697074 -0.018424  1.183020  0.053210
# 6  -0.645277 -0.657593 -0.147321 -0.936566 -0.713068  1.541715
# 7  -0.936718 -0.123463 -0.882469  1.956649  2.065784  0.331482
# 8  -0.772168 -0.916178  0.325577  0.368857 -1.684583  0.334296
# 9  -0.670051  1.955545  1.284318  1.447227 -0.213118  0.930125
# 10 -0.663139 -0.755176  0.286851  0.879633  0.958155 -1.273080
# 11 -0.036307 -0.906995  0.378504 -0.810818 -0.297856 -0.186563
# 12 -0.918887  0.276249 -0.075122  0.799493  0.151841 -0.693912
# 13 -0.572672  0.986281  0.367430  1.486960  0.442251 -0.630984
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.A.plot()
# Out:
# <AxesSubplot:>

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant',
'rabbit', 'giraffe', 'coyote', 'horse']
df2 = pd.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)

# %%
df2
# Out:
#           speed  lifespan
# snail       0.1       2.0
# pig        17.5       8.0
# elephant   40.0      70.0
# rabbit     48.0       1.5
# giraffe    52.0      25.0
# coyote     69.0      12.0
# horse      88.0      28.0

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.loc[['snail','pig','elephant'],['speed']].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df3.iloc[:3,0].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c7d6f7d319e2> in <module>
# ----> 1 df3.iloc[:3,0].plot.bar()
#
# NameError: name 'df3' is not defined

# %%
df2.iloc[:3].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'speed'}>,
#        <AxesSubplot:title={'center':'lifespan'}>], dtype=object)

# %%
a=df2.plot.bar(subplots=True)
a[0]
# Out:
# <AxesSubplot:title={'center':'speed'}>

# %%
df2.plot.bar(stacked=True,rot=45)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(15,6),
index=pd.date_range('1/1/2000',
   periods=15),
columns=list('ABCDEF'))

# %%
# Out:
#                    A         B         C         D         E         F
# 2000-01-01  0.130282  2.255044 -0.836192 -0.831615  0.303854  0.344360
# 2000-01-02 -0.412884 -1.133984  0.806053  2.167014 -0.260615  1.389770
# 2000-01-03  1.152530  0.368723  0.345713  1.629191  0.467373 -0.864899
# 2000-01-04  0.539924  0.811241  0.301943 -0.949835 -0.576847  0.888249
# 2000-01-05 -1.065979 -1.011441 -1.149770 -1.596118  0.149210  0.378675
# 2000-01-06  2.053578  0.101471 -0.015154  0.738358 -0.642241  0.396418
# 2000-01-07  1.084159 -0.070790 -2.265217  2.318656 -0.945325  0.708006
# 2000-01-08  0.332624  1.023368 -2.230035 -0.094754  0.799061  0.337958
# 2000-01-09  0.835194 -0.453555  0.755412  1.633830 -0.871958 -0.756661
# 2000-01-10 -2.021216 -1.364149 -0.282100  0.146652  0.516089 -0.726018
# 2000-01-11  0.062977 -0.424216  2.158718  1.010432 -1.315470 -0.086882
# 2000-01-12  1.197062  1.755493 -0.385367 -0.434574  0.717430 -0.675195
# ...

# %%
df.plot.bar(y=['A','B'],subplots=True,rot=45)
# Out:
# array([<AxesSubplot:title={'center':'A'}>,
#        <AxesSubplot:title={'center':'B'}>], dtype=object)

# %%
df = pd.DataFrame({'lab':['A', 'B', 'C'], 'val':[10, 30, 20]})
df
# Out:
#   lab  val
# 0   A   10
# 1   B   30
# 2   C   20

# %%
df.plot.bar(x="lab",y="val")
# Out:
# <AxesSubplot:xlabel='lab'>

# %%
df = pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# %%
df
# Out:
#             a         b         c
# 0    1.447169 -1.430240  0.263245
# 1    1.628044 -1.479773 -1.543182
# 2   -1.645843 -1.525730 -1.673753
# 3    1.694438  2.117011 -0.596458
# 4   -0.401573  1.048964  0.240165
# ..        ...       ...       ...
# 995  0.744313 -2.348759 -0.535807
# 996  1.623723 -0.349558 -1.649886
# 997  2.867071  1.173203 -1.219787
# 998  2.446223 -0.024868 -1.671448
# 999  0.413013 -1.353243 -1.543499
#
# [1000 rows x 3 columns]

# %%
df.plot.hist(2)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df=pd.DataFrame(data={"a":np.random.choice([0,1],100),"b":np.random.choice([0,1],100)})

# %%
df
# Out:
#     a  b
# 0   1  0
# 1   0  1
# 2   1  1
# 3   1  1
# 4   0  1
# .. .. ..
# 95  0  1
# 96  1  1
# 97  1  0
# 98  0  0
# 99  1  1
#
# [100 rows x 2 columns]

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.a.value_counts()
# Out:
# 0    52
# 1    48
# Name: a, dtype: int64

# %%
df.a.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = pd.DataFrame(np.random.randn(10, 4),
   index = pd.date_range('1/1/2000', periods=10),
   columns = ['A', 'B', 'C', 'D'])

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.462492 -0.127669 -0.457489 -0.200275
# 2000-01-02 -0.670307 -0.996765 -0.600805  0.930707
# 2000-01-03  1.017996  0.847569 -0.038960  0.830255
# 2000-01-04 -1.206353  0.133002 -0.995317 -0.734017
# 2000-01-05 -0.314566  0.198985 -0.441032 -1.463314
# 2000-01-06  1.122656  0.744913 -0.789481  0.064438
# 2000-01-07 -1.876801  1.684997  0.195580 -1.372134
# 2000-01-08  2.121874  1.847369 -0.690116  1.813703
# 2000-01-09 -2.294559  0.400298 -0.837086  0.385399
# 2000-01-10 -0.716722 -0.739435  1.140581 -0.857517

# %%
df.A.plot()
# Out:
# <AxesSubplot:>

# %%
df.A.pct_change().plot()
# Out:
# <AxesSubplot:>

# %%
df[["A","B"]].rolling(3).mean().plot.bar()
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd
s= pd.Series([2, np.nan, 5, -1, 0])
s
# Out:
# 0    2.0
# 1    NaN
# 2    5.0
# 3   -1.0
# 4    0.0
# dtype: float64

# %%
s.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
data=np.random.randn(25,4)

# %%
df=pd.DataFrame(data,columns=list("ABCD"))
df
# Out:
#            A         B         C         D
# 0  -1.358209 -0.765408  0.932979  0.644536
# 1   0.375816  1.664338  1.566407 -0.148017
# 2  -0.631369  1.351319 -0.917776  0.484453
# 3  -0.775418 -0.771124  1.257054 -0.211095
# 4   1.604672  0.120336  0.000576 -0.281257
# 5  -0.053173  0.948485 -0.792869  0.730264
# 6  -1.344776  0.740790 -0.046670  0.126923
# 7  -1.211785  1.075368  1.304762 -1.341742
# 8  -0.990898 -1.546143 -0.740822  0.408355
# 9   0.995972  1.320202 -0.075933  1.100433
# 10  0.057333  1.628560  2.095861  0.172351
# 11  0.692911  0.371933  0.194822  0.232033
# 12  0.473521  0.843324 -0.172772 -0.505456
# 13  0.352329 -1.729506 -1.820772  1.218363
# 14 -0.629757  0.045190 -0.208857  0.228397
# 15 -2.599442  0.618380 -1.094951  0.563366
# 16 -0.294807 -0.410195  0.234467  0.164174
# 17 -0.786813  1.102396  0.870586 -0.006816
# 18  1.047019  1.119244 -1.558357 -0.129681
# 19 -1.047909  0.479260 -0.053570  0.673483
# 20 -0.541661 -1.012056  0.565052  0.061768
# ...

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10, 2),
                  columns=['Col1', 'Col2'])
df
# Out:
#        Col1      Col2
# 0 -0.435248  0.307590
# 1 -0.023440  0.389702
# 2  0.427079 -0.236925
# 3 -0.396459  0.187106
# 4  1.239644 -0.248657
# 5  0.438508  0.441563
# 6  0.162406  0.973715
# 7  0.650738  1.024940
# 8  0.049554  0.758258
# 9 -1.459649 -1.940991

# %%
df["x"]=pd.Series(["A","A","A","A","A","b","b","b","b","b"])

# %%
df
# Out:
#        Col1      Col2  x
# 0 -0.435248  0.307590  A
# 1 -0.023440  0.389702  A
# 2  0.427079 -0.236925  A
# 3 -0.396459  0.187106  A
# 4  1.239644 -0.248657  A
# 5  0.438508  0.441563  b
# 6  0.162406  0.973715  b
# 7  0.650738  1.024940  b
# 8  0.049554  0.758258  b
# 9 -1.459649 -1.940991  b

# %%
df.boxplot(by="x")
# Out:
# array([<AxesSubplot:title={'center':'Col1'}, xlabel='[x]'>,
#        <AxesSubplot:title={'center':'Col2'}, xlabel='[x]'>], dtype=object)

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10, 3),
                  columns=['Col1', 'Col2', 'Col3'])
df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A',
                     'B', 'B', 'B', 'B', 'B'])
df['Y'] = pd.Series(['A', 'B', 'A', 'B', 'A',
                     'B', 'A', 'B', 'A', 'B'])

# %%
df
# Out:
#        Col1      Col2      Col3  X  Y
# 0  0.741902 -1.371849 -1.188174  A  A
# 1 -0.972481  0.159732 -1.559970  A  B
# 2 -1.687915 -0.013620 -0.138798  A  A
# 3 -0.632028 -0.137381  3.674991  A  B
# 4  1.513312 -0.170291 -0.366224  A  A
# 5 -1.587403  1.799016 -0.200153  B  B
# 6  0.791064 -1.004840  1.767385  B  A
# 7  0.818589 -0.364667  1.157023  B  B
# 8  0.776387 -1.006368  0.910967  B  A
# 9  0.929300  0.500857 -0.399563  B  B

# %%
df.boxplot(by=["X","Y"])
# Out:
# array([[<AxesSubplot:title={'center':'Col1'}, xlabel='[X, Y]'>,
#         <AxesSubplot:title={'center':'Col2'}, xlabel='[X, Y]'>],
#        [<AxesSubplot:title={'center':'Col3'}, xlabel='[X, Y]'>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df = pd.DataFrame({
    'x': [1, 2, 2.5, 3, 3.5, 4, 5],
    'y': [4, 4, 4.5, 5, 5.5, 6, 6],
})
df
# Out:
#      x    y
# 0  1.0  4.0
# 1  2.0  4.0
# 2  2.5  4.5
# 3  3.0  5.0
# 4  3.5  5.5
# 5  4.0  6.0
# 6  5.0  6.0

# %%
df.plot.hist(bins=12)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2 = pd.DataFrame(
    np.random.randint(1, 7, 6000),
    columns = ['one'])
df2
# Out:
#       one
# 0       2
# 1       1
# 2       6
# 3       3
# 4       1
# ...   ...
# 5995    5
# 5996    1
# 5997    4
# 5998    5
# 5999    5
#
# [6000 rows x 1 columns]

# %%
df.plot.hist(bins=12)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = pd.DataFrame({
    'length': [1.5, 0.5, 1.2, 0.9, 3],
    'width': [0.7, 0.2, 0.15, 0.2, 1.1]
    }, index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])
df
# Out:
#          length  width
# pig         1.5   0.70
# rabbit      0.5   0.20
# duck        1.2   0.15
# chicken     0.9   0.20
# horse       3.0   1.10

# %%
df.hist(bins=3)
# Out:
# array([[<AxesSubplot:title={'center':'length'}>,
#         <AxesSubplot:title={'center':'width'}>]], dtype=object)

# %%
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],
                   'radius': [2439.7, 6051.8, 6378.1]},
                  index=['Mercury', 'Venus', 'Earth'])
df
# Out:
#          mass  radius
# Mercury  0.33  2439.7
# Venus    4.87  6051.8
# Earth    5.97  6378.1

# %%
df.plot.pie(subplots=True, figsize=(10,10))
# Out:
# array([<AxesSubplot:ylabel='mass'>, <AxesSubplot:ylabel='radius'>],
#       dtype=object)

# %%
df = pd.DataFrame(
    np.random.randn(5,3),
    columns = ['one', "two", "three"])
df
# Out:
#         one       two     three
# 0  3.679346  0.566937  0.579077
# 1  0.337256  1.425124 -0.571451
# 2  0.746603 -1.582747 -0.549209
# 3 -0.388109  0.335785 -0.440911
# 4  0.075194  0.923817 -0.177340

# %%
df.fillna
# Out:
# <bound method DataFrame.fillna of         one       two     three
# 0  3.679346  0.566937  0.579077
# 1  0.337256  1.425124 -0.571451
# 2  0.746603 -1.582747 -0.549209
# 3 -0.388109  0.335785 -0.440911
# 4  0.075194  0.923817 -0.177340>

# %%
df[df < 0] = 0
df
# Out:
#         one       two     three
# 0  3.679346  0.566937  0.579077
# 1  0.337256  1.425124  0.000000
# 2  0.746603  0.000000  0.000000
# 3  0.000000  0.335785  0.000000
# 4  0.075194  0.923817  0.000000

# %%
df.plot.pie(subplots=True, figsize=(10,10))
# Out:
# C:\Users\C\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='one'>, <AxesSubplot:ylabel='two'>,
#        <AxesSubplot:ylabel='three'>], dtype=object)

# %%
df = pd.DataFrame([[5.1, 3.5, 0], [4.9, 3.0, 0], [7.0, 3.2, 1],
                   [6.4, 3.2, 1], [5.9, 3.0, 2]],
                  columns=['length', 'width', 'species'])

# %%
df
# Out:
#    length  width  species
# 0     5.1    3.5        0
# 1     4.9    3.0        0
# 2     7.0    3.2        1
# 3     6.4    3.2        1
# 4     5.9    3.0        2

# %%
df.plot.scatter(x="length",y="width", c="darkblue", colormap="viridis",s=100)
# Out:
# <AxesSubplot:xlabel='length', ylabel='width'>

# %%
df = pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# %%
df
# Out:
#             a         b         c
# 0    1.967754 -0.239511 -1.009663
# 1    0.817518  0.383882  0.128756
# 2    0.535012  0.442451 -2.089828
# 3    1.149786  1.636082 -2.229573
# 4    1.330734 -0.377375 -0.060435
# ..        ...       ...       ...
# 995  2.541653  0.258838 -2.486075
# 996  2.822839  0.084795 -1.232477
# 997 -1.050334  0.117322 -1.060402
# 998  1.809645  1.289698 -1.524202
# 999  1.582103  0.197061  0.577340
#
# [1000 rows x 3 columns]

# %%
df.plot.scatter(x="a",y="b",title="Saçılım Grafiği",s=20,grid=True)
# Out:
# <AxesSubplot:title={'center':'Saçılım Grafiği'}, xlabel='a', ylabel='b'>

# %%
df = pd.DataFrame({
    'x': [1, 2, 2.5, 3, 3.5, 4, 5],
    'y': [4, 4, 4.5, 5, 5.5, 6, 6],
})
df
# Out:
#      x    y
# 0  1.0  4.0
# 1  2.0  4.0
# 2  2.5  4.5
# 3  3.0  5.0
# 4  3.5  5.5
# 5  4.0  6.0
# 6  5.0  6.0

# %%
fig=plt.figure(figsize=(5,2))
ax=fig.add_axes([0,1,0.5,1])
l1=ax.plot(df.x)
ax=fig.add_axes([1,0,0.5,2])
l1=ax.plot(df.y)
l1=ax.plot(df.x+df.y)
ax.set_title("graps")
ax.set_xlabel('Div/2')
ax.set_ylabel('Marks_scored')
plt.show()

# %%
fig=plt.figure(figsize=(5,2))
fig.add_axes([0,1,0.5,1]).plot(df.x)
fig.add_axes([1,0,0.5,2]).plot(df.y)


ax.set_title("graps")
ax.set_xlabel('Div/2')
ax.set_ylabel('Marks_scored')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-25201b0eae45> in <module>
#       1 fig=plt.figure(figsize=(5,2))
#       2 fig.add_axes([0,1,0.5,1]).plot(df.x)
# ----> 3 fig.add_axes([1,0,0.5,2]).plot(df.y)+plot(df.x+df.y)
#       4
#       5
#
# NameError: name 'plot' is not defined

# %%
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt
import seaborn as sns

# %%
plt.subplot(2,3,(1,4))

plt.subplot(232)
plt.subplot(233)

plt.subplot(235)
plt.subplot(236)
# Out:
# <AxesSubplot:>

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot([1,5,8])

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot([1,5,9])
ax2=fig.add_subplot(3,5,8)
ax2.plot([-1,-5],[3,8])

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.plot([1,5,9])
ax2=fig.add_subplot(2,2,1)
ax2.plot([1,5,9])

# %%
fig=plt.figure()
ax1=fig.add_subplot(121)
ax1.plot([1,5,9])
ax2=fig.add_subplot(1,2,2)
ax2.plot([1,5,9])
ax2=fig.add_subplot(2,2,3,facecolor="y")
ax2.plot([1,5,9])

# %%
fig=plt.figure()
ax1=fig.add_subplot(121)
ax1.plot([1,5,9])
ax2=fig.add_subplot(223, facecolor="y")
ax2.plot([1,5])
ax3=fig.add_subplot(122)
ax3.plot([1,5])

# %%
#fig=plt.figure()
fig,ax=plt.subplots(2,2, figsize=(12,10))
x=np.arange(1,5)

ax[0,0].plot(x,1/x, "r")
ax[0,1].plot(x*x,x, "b")
ax[1,0].plot(x,x*x*x, "k")
ax[1,1].plot(np.sin(x),x,"m")

ax[0][0].set(xlabel="x label", ylabel="y label", title="başlık1")
ax[0][1].set(xlabel="x label", ylabel="y label", title="başlık2")
ax[1][0].set(xlabel="x label", ylabel="y label", title="başlık3")
ax[1][1].set(xlabel="x label", ylabel="y label", title="başlık4")
# Out:
# [Text(0.5, 0, 'x label'), Text(0, 0.5, 'y label'), Text(0.5, 1.0, 'başlık4')]

# %%
t=np.arange(1,10)
s=np.arange(1,10)

fig,ax=plt.subplots()
ax.plot(t,s*s*s)
ax.set(xlabel="x label", ylabel="ylabel", title="başlık")
ax.grid()
fig.savefig("graafik-1 deneme")

# %%
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)
fig,ax=plt.subplots()
ax.plot(t,s)
ax.set(xlabel="zaman", ylabel="voltaj", title="Zaman - Voltaj Analizi")
ax.grid()
fig.savefig('Zaman Voltaj Grafigi')

# %%
fig,ax=plt.subplots(2,2)
ax[1][1].plot([1,5,9])

# %%
fig,ax=plt.subplots(3,5,figsize=(15,5))

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

# %%
fig, (ax1,ax2)=plt.subplots(1,2)
ax1.plot(x1,y1)
ax2.plot(x2,y2)

# %%
fig, (ax1,ax2)=plt.subplots(1,2)
ax1.annotate('left',(0.5,0.5))
ax2.annotate('right',(0.5,0.5))
# Out:
# Text(0.5, 0.5, 'right')

# %%
from matplotlib import pyplot as plt
fig,  ax=plt.subplots(2,3)
ax[0,1].plot([3,5,9])

# %%
rows, cols=2,4
fig,ax=plt.subplots(rows,cols,sharey=True)

for row in range(rows):
    for col in range(cols):
            ax[row,col].text(0.5,0.5, "satır"+str(row)+" "+"sütun"+str(col),
                    color="blue", 
                    fontsize=8,
                    ha="center")

plt.show()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(4,2,(4,6)).plot([0,2,3,4])
plt.subplot(421).plot(x1,y1,"r")
plt.subplot(422).plot(x2,y2,"y")
plt.subplot(423).plot(-x1,y2,"ob")
plt.subplot(425).plot(2*x2,y2*y2,"+k")
plt.subplot(427).plot(-x2,-y1,"xb")
plt.subplot(428).plot(-y1,y2,"*r")

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)
K={ 0:(x1,y1,"r"),1:(x2,y2),2:(x1,y1),3:(x2,y2),4:(x1,y1),5:(x2,y2),6:(x1,y1),7:(x2,y2)}
z=0


m,k=4,2
s=[1,2,3,(4,6),5,7,8]
for i in s:
    plt.subplot(m,k,i).plot(K[z]) 
    z+=1
plt.show()
# Out:
# C:\Users\C\anaconda3\lib\site-packages\numpy\core\_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-49b2318620bf> in <module>
#      10 s=[1,2,3,(4,6),5,7,8]
#      11 for i in s:
# ---> 12     plt.subplot(m,k,i).plot(K[z])
#      13     z+=1
#      14 plt.show()
#
# ...

# %%
K={ 0:"x1,y1,"r" ",
   1:" x2,y2" ,
   2:" x1,y1" ,
   3:" x2,y2" ,
   4:" x1,y1",
   5:" x2,y2" ,
   6:" x1,y1" ,
   7:" x2,y2"}

print(K[1])
# Out:
#  x2,y2

# %%
S=[(4,2,(4,6)),(4,2,1),(4,2,2),(4,2,3),(4,2,5),(4,2,7),(4,2,8)]
for a,b,c in S:
    plt.subplot(a,b,c)
plt.show()

# %%
Z=[(4,2,(4,6)),(4,2,1),(4,2,2),(4,2,3),(4,2,5),(4,2,7),(4,2,8)]
for a,b,c in Z:
    ax=plt.subplot(a,b,c)
    ax.annotate( [c],(0.1,0.1),color="blue",  fontsize=8, ha="center")    
    ax.plot() 
plt.show()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)


K={ 0:"x1,y1" }

m,k=4,2
z=0
s=[1]
for i in s:
     for a,b in A:
        plt.subplot(m,k,i).plot(a,b)
    z+=1
plt.show()

# %%
x= np.linspace(0.0, 5.0)

m,k=4,2
df1=pd.Series( 1,2,3,46,5,7,8)
df2=pd.Series("r","y","*b","-b","+k","xb","*r")
df3=pd.Series( x, x*2 , x**3,np.sin(x),np.cos(x),1/x,np.exp(-x1))
df4=pd.Series( "x", "x*2" , "x**3","sin(x)","np.cos(x)"  ,"np.ln(x))")


dfZ=pd.concat([df1,df2,df3,df4])


A=((1,x1,y1,"r"),
   (2,x2,y2,"y"),
   (3,-x1,-y2,"*b"),
   ((4,6),x1,-x2*x2,"-b"),
   (5,2*x2,y2*y2,"+k"),
   (7,-x2,-y1,"xb"),
   (8,-y1,y2,"*r"))

for a,b,c,d in A:
    ax=plt.subplot(m,k,a)
    ax.plot(b,c,d)
    
    ax.text( 0.5,0.5,  ({a}) ,color="magenta", fontsize=8,ha="left")
    ax.set(xlabel="x eksen", ylabel="y eksen", label="başlık")
    #ax.legend(label="başlık",loc="upper right")
    ax.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-175-ef3728c820e0> in <module>
#       2
#       3 m,k=4,2
# ----> 4 df1=pd.Series( 1,2,3,46,5,7,8)
#       5 df2=pd.Series("r","y","*b","-b","+k","xb","*r")
#       6 df3=pd.Series( x, x*2 , x**3,np.sin(x),np.cos(x),1/x,np.exp(-x1))
#
# TypeError: __init__() takes from 1 to 7 positional arguments but 8 were given

# %%
#x= np.linspace(0.0, 5.0)

m,k=4,2
#df1=pd.Series(1,2,3,4,5,6)
f1=(1,2,3,4,5,6,7)
f2=("r","y","*b","-b","+k","xb","*r")
f3=( "x", "x*2" , " x**3","np.sin(x)","np.cos(x)"  ,"1/x","np.exp(-x1)")
f4=( "x", "x*2" , "x**3","sin(x)","cos(x)"  ,"1/x","exp(-x1)")

df1=pd.DataFrame(f1,columns=["position"])
df2=pd.DataFrame(f2 ,columns=["colour"])
df3=pd.DataFrame(f3 ,columns=["fonction"])
df4=pd.DataFrame(f4 ,columns=["name"])
df=pd.concat([df1,df2,df3,df4], axis=1)

df
# Out:
#    position colour     fonction      name
# 0         1      r            x         x
# 1         2      y          x*2       x*2
# 2         3     *b         x**3      x**3
# 3         4     -b    np.sin(x)    sin(x)
# 4         5     +k    np.cos(x)    cos(x)
# 5         6     xb          1/x       1/x
# 6         7     *r  np.exp(-x1)  exp(-x1)

# %%
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt

# %%
K=[]
s=[1,2,3,(4,6),5,7,8]
Z=(( x1,y1 ),
   ( x2,y2 ),
   ( x2,y2 ),( x2,y2 ),( x2,y2 ),( x2,y2 ),( x2,y2 ),( x2,y2 ))
for i in s:
    K.append(i)
K
# Out:
# [1, 2, 3, (4, 6), 5, 7, 8]

# %%
 
a = ["This" , "is", "a", "sample", "program"]
 
b = [10, 2, 45, 3, 5, 7, 8, 10]
 
newlist=[]
for i in range(4):
    newlist[i]=str(a[i])+","+str(b[i])

print(newlist)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-e87c62e11636> in <module>
#       5 newlist=[]
#       6 for i in range(4):
# ----> 7     newlist[i]=str(a[i])+","+str(b[i])
#       8
#       9 print(newlist)
#
# IndexError: list assignment index out of range

# %%
name_list = ['Harry', 'Hermione', 'Ginny']
age_list = [17, 18, 19]
for i in range(3)
    m= [j for i in zip(name_list, age_list) for j in i]
print(mu)
# Out:
#   File "<ipython-input-161-05d5aea62fd0>", line 3
#     for i in range(3)
#                      ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame({'a': [1,2,3], 'b': [2,3,4], 'c':['dd','ee','ff'], 'd':[5,9,1]}=_+-[]
# Out:
#    a  b   c  d
# 0  1  2  dd  5
# 1  2  3  ee  9
# 2  3  4  ff  1

# %%
df['e'] = df.sum(axis=1)
df
# Out:
#    a  b   c  d   e
# 0  1  2  dd  5   8
# 1  2  3  ee  9  14
# 2  3  4  ff  1   8

# %%
df["e"]=df.sum(axis=1)

# %%
}}""}}""}}""}}""}}""}}"}}""[[]]{{}}

# %%
ri.drop(["county_name","state" ], axis=1, inplace=True)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sb

# %%
def cosplot(y=1):
    x=np.linspace(0,20,100)
    for i in range(1,5):
        plt.plot(x,np.cos((x+i*5)*y))

# %%
sb.set_style("darkgrid")
current_palette=sb.color_palette()

# %%
sb.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sb.color_palette("viridis",19)
# Out:
# [(0.280267, 0.073417, 0.397163),
#  (0.282623, 0.140926, 0.457517),
#  (0.273006, 0.20452, 0.501721),
#  (0.253935, 0.265254, 0.529983),
#  (0.229739, 0.322361, 0.545706),
#  (0.206756, 0.371758, 0.553117),
#  (0.183898, 0.422383, 0.556944),
#  (0.163625, 0.471133, 0.558148),
#  (0.144759, 0.519093, 0.556572),
#  (0.127568, 0.566949, 0.550556),
#  (0.119423, 0.611141, 0.538982),
#  (0.134692, 0.658636, 0.517649),
#  (0.185783, 0.704891, 0.485273),
#  (0.266941, 0.748751, 0.440573),
#  (0.369214, 0.788888, 0.382914),
#  (0.477504, 0.821444, 0.318195),
#  (0.606045, 0.850733, 0.236712),
#  (0.741388, 0.873449, 0.149561),
#  (0.876168, 0.891125, 0.09525)]

# %%
sb.color_palette("Accent",19)
# Out:
# [(0.4980392156862745, 0.788235294117647, 0.4980392156862745),
#  (0.7450980392156863, 0.6823529411764706, 0.8313725490196079),
#  (0.9921568627450981, 0.7529411764705882, 0.5254901960784314),
#  (1.0, 1.0, 0.6),
#  (0.2196078431372549, 0.4235294117647059, 0.6901960784313725),
#  (0.9411764705882353, 0.00784313725490196, 0.4980392156862745),
#  (0.7490196078431373, 0.3568627450980392, 0.09019607843137253),
#  (0.4, 0.4, 0.4),
#  (0.4980392156862745, 0.788235294117647, 0.4980392156862745),
#  (0.7450980392156863, 0.6823529411764706, 0.8313725490196079),
#  (0.9921568627450981, 0.7529411764705882, 0.5254901960784314),
#  (1.0, 1.0, 0.6),
#  (0.2196078431372549, 0.4235294117647059, 0.6901960784313725),
#  (0.9411764705882353, 0.00784313725490196, 0.4980392156862745),
#  (0.7490196078431373, 0.3568627450980392, 0.09019607843137253),
#  (0.4, 0.4, 0.4),
#  (0.4980392156862745, 0.788235294117647, 0.4980392156862745),
#  (0.7450980392156863, 0.6823529411764706, 0.8313725490196079),
# ...

# %%
sb.set_palette("Reds",19)
sb.set_style("darkgrid",rc={"ytic.left":True})
cosplot()

# %%
sb.set_context()

# %%
sb.plotting_context()
# Out:
# {'font.size': 10.0,
#  'axes.labelsize': 'medium',
#  'axes.titlesize': 'large',
#  'xtick.labelsize': 'medium',
#  'ytick.labelsize': 'medium',
#  'legend.fontsize': 'medium',
#  'axes.linewidth': 0.8,
#  'grid.linewidth': 0.8,
#  'lines.linewidth': 1.5,
#  'lines.markersize': 6.0,
#  'patch.linewidth': 1.0,
#  'xtick.major.width': 0.8,
#  'ytick.major.width': 0.8,
#  'xtick.minor.width': 0.6,
#  'ytick.minor.width': 0.6,
#  'xtick.major.size': 3.5,
#  'ytick.major.size': 3.5,
#  'xtick.minor.size': 2.0,
#  'ytick.minor.size': 2.0,
#  'legend.title_fontsize': None}

# %%
tips=sb.load_dataset("tips")
sb.set_style
np.random.seed(0)
x=np.random.randn(100)
ax=sb.histplot(x)

# %%
diamonds=sb.load_dataset('diamonds')
exercise=sb.load_dataset('exercise')
flights=sb.load_dataset('flights')
geyser=sb.load_dataset('geyser')
iris=sb.load_dataset('iris')
penguins=sb.load_dataset('penguins')
planets=sb.load_dataset('planets')
mpg=sb.load_dataset('mpg')
tips = sb.load_dataset('tips')
titanic=sb.load_dataset('titanic')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-604c2410ba9e> in <module>
# ----> 1 diamonds=sb.load_dataset('diamonds')
#       2 exercise=sb.load_dataset('exercise')
#       3 flights=sb.load_dataset('flights')
#       4 geyser=sb.load_dataset('geyser')
#       5 iris=sb.load_dataset('iris')
#
# NameError: name 'sb' is not defined

# %%
x=np.random.randn(100)
ax=sb.displot(x)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sb.stripplot(x="time",y="tip",data=tips, order=["Dinner","Lunch"],hue="smoker")
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sb.swarmplot(x="species",y="sepal_width", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
sb.swarmplot(x="class",y="fare", data=titanic)
# Out:
# C:\Users\C\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\C\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 69.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\C\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 84.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
sb.boxplot(x="class",y="fare", data=titanic)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sb.boxplot(x="alive",y="age",hue="sex", data=titanic)
# Out:
# <AxesSubplot:xlabel='alive', ylabel='age'>

# %%
sb.stripplot(x="fare",y="sex", data=titanic)
sb.stripplot(x="fare",y="sex", data=titanic)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='sex'>

# %%
sb.stripplot(x="sex",y="age",data=titanic,hue="class")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
df=sb.load_dataset("exercise")
df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
sb.catplot(y="pulse",x="time",hue="kind",col="diet",kind="violin",data=df,palette="viridis")

# %%
df=sb.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sb.catplot( x = "who", col = "class",data = titanic, kind = "count", col_wrap = 3,palette="viridis")

# %%
g=sb.PairGrid(penguins,hue="species",palette="viridis")
g.map_diag(sb.histplot)
g.map_offdiag(sb.scatterplot)
g.add_legend()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
a=tips.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
b=tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sb.set_palette("viridis",5)
sb.set_style("whitegrid")
current_palette=sb.color_palette()

# %%
g=sb.FacetGrid(titanic,col="day",row="time")
g.map(sb.scatterplot, "total_bill","tip")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2b24c1673f8b> in <module>
# ----> 1 g=sb.FacetGrid(titanic,col="day",row="time")
#       2 g.map(sb.scatterplot, "total_bill","tip")
#
# NameError: name 'titanic' is not defined

# %%
titanic.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-cdd760b19866> in <module>
# ----> 1 titanic.head()
#
# NameError: name 'titanic' is not defined

# %%
titanic.sex[titanic.who=="child"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5aafced5191a> in <module>
# ----> 1 titanic.sex[titanic.who=="child"].value_counts()
#
# NameError: name 'titanic' is not defined

# %%
fig=plt.figure(figsize=(10,5))
titanic=sb.load_dataset("titanic")
sb.heatmap(titanic.corr(),annot=False)
# Out:
# <AxesSubplot:>

# %%
g=sb.FacetGrid(titanic,col="class",row="sex",hue="who")
g.map(sb.scatterplot, "age","fare")
g.add_legend()

# %%
g=sb.FacetGrid(titanic, col='who', row='class')
g.map(sb.barplot, 'alive', 'age')
# Out:
# C:\Users\C\anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.sex[titanic.who=="child"].value_counts()
# Out:
# female    43
# male      40
# Name: sex, dtype: int64

# %%
a=titanic[titanic.pclass==2]
veri=pd.crosstab(a.who, a.sex)
veri
# Out:
# sex    female  male
# who
# child      10     9
# man         0    99
# woman      66     0

# %%
# 2. sınıf ta bulunan çocukların sayısını 

a=titanic[titanic.pclass==2]
b=pd.crosstab(a.who, a.sex)
b.loc["child","male"]
# Out:
# 9

# %%
titanic=sb.load_dataset("titanic")

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic[titanic.who=="child"][titanic.sex=="male"][titanic.pclass==2].who.value_counts()
# Out:
# <ipython-input-47-7fd8d6eaea00>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic[titanic.who=="child"][titanic.sex=="male"][titanic.pclass==2].who.value_counts()
# <ipython-input-47-7fd8d6eaea00>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic[titanic.who=="child"][titanic.sex=="male"][titanic.pclass==2].who.value_counts()
# child    9
# Name: who, dtype: int64

# %%
pd.pivot_table(titanic,index="who",columns="sex",values="pclass",aggfunc=np.sum)
# Out:
# sex    female    male
# who
# child   113.0   105.0
# man       NaN  1274.0
# woman   565.0     NaN

# %%
veri=pd.pivot_table(ri_weather,values='is_arrested', index='rating',columns='violation',
                    aggfunc=np.mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-e8d8ef93433a> in <module>
# ----> 1 veri=pd.pivot_table(ri_weather,values='is_arrested', index='rating',columns='violation',
#       2                     aggfunc=np.mean)
#
# NameError: name 'ri_weather' is not defined

# %%
["child","male","2"].value_counts()

# %%
# Out:
#                  0                                                  1
# 0  (child, female)       survived  pclass     sex    age  sibsp  p...
# 1    (child, male)       survived  pclass   sex    age  sibsp  par...
# 2      (man, male)       survived  pclass   sex   age  sibsp  parc...
# 3  (woman, female)       survived  pclass     sex   age  sibsp  pa...

# %%
{<<>>????????>>>><<::"""""""}}{{{{{|||||}}}}}}}}{{"""""""""::::?????>>>><<<<<}}

# %%
Hepsi object yani problemli  
çok sayıda % 98 none değeri olan yerler var. 
amaç burda kurtulmak değil veri manip=ülasyon .Her sütun doldurulacak. none değer kalmasın


1. null değerler doldurulacak
2. "her bir e sayısallaştırılacak
feauture engineering yapılıp önemli önensiz ayırılap önemsizlerden kurtulunacak.
get dummies ile sayısallaştırılacak


bir sütunla ilgili işlem yapılırken diğer tüm sütunların hesaba katılarak işlem yapılabilir (doldurulabilin)
# Out:
#   File "<ipython-input-28-192a6c9a615c>", line 1
#     Hepsi object yani problemli
#           ^
# SyntaxError: invalid syntax

# %%
pd.concat([df1,df2,df3])
pd.concat([df1,df2,df3],axis=1)
df1=pd.DataFrame({'A':['A0','A1','A2',],
                 'B':['B0','B1','B2','B3'],
                 'C':['C0','C1','C2','C3'],
                 'D':['D0','D1','D2','D2']},
                index:[0,1,2,3])

# %%
df2=pd.DataFrame({'A':['A4','A5','A5','A6','A7'],
                 'B':['B4','B4','B5','B6','B7'],
                'C':['C4','C5','C6','C7','C8'],
                  'D':['D8','D9','D10','D11','D12']}),
                index=[4,5,6,7])

# %%
pd.concat([df1,df2,df3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ecf08e82d92a> in <module>
# ----> 1 pd.concat([df1,df2,df3])
#
# NameError: name 'df1' is not defined

# %%
import nbformat 
# Readnig the notebooks
    nb1=nbformat.read('Pandas_notebook.jpynb')

    for i in range(len(a)):
        libte.append(a[i]*b[i])
liste
a1=np.array(a)
